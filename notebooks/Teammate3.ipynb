# %%
import pandas as pd

fundamentalsdf = pd.read_csv('https://www.kaggle.com/datasets/dgawlik/nyse?select=fundamentals.csv', on_bad_lines='skip')
splitadjustedpricesdf = pd.read_csv('https://www.kaggle.com/datasets/dgawlik/nyse?select=prices-split-adjusted.csv', on_bad_lines='skip')
pricesdf = pd.read_csv('https://www.kaggle.com/datasets/dgawlik/nyse?select=prices.csv', on_bad_lines='skip')
securitiesdf = pd.read_csv('https://www.kaggle.com/datasets/dgawlik/nyse?select=securities.csv', on_bad_lines='skip')

print(fundamentalsdf.to_string())
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                     <!DOCTYPE html>
# 0                                                                                                                                                                                                                                                                                                                                                                                                  <html lang="en">
# ...
